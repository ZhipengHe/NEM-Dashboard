# %%
import requests
import os
import time
import os
import pandas as pd

# Define directories
data_dir = 'data/aemo_data'
out_dir = 'data/concatenated_data'
analysis_dir = 'data/analysis'
os.makedirs(out_dir, exist_ok=True)
# Create directory to store files
os.makedirs(data_dir, exist_ok=True)
os.makedirs(analysis_dir, exist_ok=True)


# List of states/regions
regions = ['NSW1', 'QLD1', 'SA1', 'TAS1', 'VIC1']

# %% [markdown]
# ## Price

# %%
# Base URL template
base_url = "https://aemo.com.au/aemo/data/nem/priceanddemand/PRICE_AND_DEMAND_{}_{}.csv"

# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Loop through years and months
for year in range(2019, 2025):
    for month in range(1, 13):
        month_str = f"{year}{month:02d}"
        if year == 2024 and month > 12:
            continue
        for region in regions:
            filename = f"data/aemo_data/PRICE_AND_DEMAND_{month_str}_{region}.csv"
            # Skip if file already exists
            if os.path.exists(filename):
                print(f"Skipping {filename} - already exists")
                continue
                
            url = base_url.format(month_str, region)
            try:
                response = requests.get(url, headers=headers)
                response.raise_for_status()
                with open(filename, 'wb') as f:
                    f.write(response.content)
                print(f"Downloaded {filename}")
            except requests.exceptions.RequestException as e:
                print(f"Failed to download {url}: {e}")
            time.sleep(1)  # Wait 1 second between requests
# Out:
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201901_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201901_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201901_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201901_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201901_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201902_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201902_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201902_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201902_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201902_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201903_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201903_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201903_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201903_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201903_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201904_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201904_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201904_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201904_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201904_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201905_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201905_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201905_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201905_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201905_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201906_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201906_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201906_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201906_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201906_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201907_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201907_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201907_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201907_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201907_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201908_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201908_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201908_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201908_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201908_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201909_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201909_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201909_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201909_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201909_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201910_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201910_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201910_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201910_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201910_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201911_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201911_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201911_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201911_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201911_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201912_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201912_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201912_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201912_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_201912_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202001_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202001_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202001_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202001_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202001_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202002_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202002_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202002_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202002_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202002_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202003_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202003_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202003_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202003_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202003_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202004_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202004_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202004_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202004_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202004_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202005_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202005_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202005_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202005_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202005_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202006_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202006_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202006_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202006_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202006_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202007_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202007_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202007_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202007_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202007_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202008_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202008_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202008_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202008_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202008_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202009_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202009_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202009_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202009_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202009_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202010_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202010_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202010_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202010_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202010_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202011_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202011_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202011_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202011_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202011_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202012_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202012_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202012_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202012_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202012_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202101_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202101_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202101_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202101_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202101_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202102_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202102_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202102_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202102_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202102_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202103_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202103_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202103_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202103_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202103_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202104_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202104_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202104_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202104_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202104_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202105_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202105_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202105_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202105_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202105_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202106_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202106_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202106_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202106_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202106_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202107_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202107_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202107_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202107_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202107_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202108_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202108_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202108_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202108_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202108_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202109_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202109_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202109_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202109_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202109_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202110_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202110_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202110_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202110_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202110_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202111_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202111_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202111_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202111_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202111_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202112_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202112_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202112_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202112_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202112_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202201_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202201_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202201_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202201_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202201_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202202_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202202_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202202_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202202_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202202_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202203_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202203_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202203_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202203_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202203_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202204_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202204_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202204_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202204_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202204_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202205_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202205_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202205_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202205_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202205_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202206_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202206_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202206_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202206_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202206_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202207_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202207_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202207_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202207_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202207_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202208_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202208_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202208_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202208_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202208_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202209_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202209_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202209_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202209_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202209_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202210_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202210_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202210_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202210_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202210_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202211_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202211_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202211_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202211_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202211_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202212_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202212_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202212_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202212_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202212_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202301_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202301_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202301_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202301_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202301_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202302_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202302_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202302_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202302_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202302_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202303_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202303_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202303_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202303_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202303_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202304_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202304_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202304_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202304_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202304_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202305_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202305_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202305_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202305_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202305_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202306_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202306_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202306_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202306_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202306_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202307_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202307_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202307_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202307_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202307_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202308_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202308_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202308_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202308_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202308_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202309_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202309_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202309_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202309_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202309_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202310_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202310_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202310_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202310_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202310_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202311_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202311_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202311_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202311_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202311_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202312_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202312_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202312_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202312_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202312_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202401_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202401_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202401_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202401_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202401_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202402_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202402_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202402_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202402_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202402_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202403_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202403_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202403_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202403_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202403_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202404_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202404_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202404_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202404_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202404_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202405_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202405_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202405_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202405_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202405_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202406_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202406_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202406_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202406_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202406_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202407_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202407_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202407_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202407_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202407_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202408_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202408_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202408_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202408_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202408_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202409_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202409_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202409_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202409_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202409_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202410_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202410_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202410_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202410_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202410_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202411_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202411_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202411_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202411_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202411_VIC1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202412_NSW1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202412_QLD1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202412_SA1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202412_TAS1.csv
# Downloaded data/aemo_data/PRICE_AND_DEMAND_202412_VIC1.csv

# %%
def concat_files_by_year_and_region():
    for year in range(2019, 2025):
        for region in regions:
            # Collect all files for the given year and region
            region_files = [
                os.path.join(data_dir, file) 
                for file in os.listdir(data_dir) 
                if file.startswith(f"PRICE_AND_DEMAND_{year}") and file.endswith(f"_{region}.csv")
            ]

            # If no files found, skip
            if not region_files:
                print(f"No files found for {year} - {region}")
                continue

            # Load and concatenate CSV files
            data_frames = []
            for file in region_files:
                try:
                    df = pd.read_csv(file)
                    data_frames.append(df)
                except Exception as e:
                    print(f"Failed to read {file}: {e}")

            # Concatenate and save the result
            if data_frames:
                concatenated_df = pd.concat(data_frames, ignore_index=True)
                output_filename = f"PRICE_AND_DEMAND_{year}_{region}.csv"
                output_path = os.path.join(out_dir, output_filename)
                concatenated_df.to_csv(output_path, index=False)
                print(f"Concatenated data saved to {output_path}")

# %%
concat_files_by_year_and_region()
# Out:
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2019_NSW1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2019_QLD1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2019_SA1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2019_TAS1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2019_VIC1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2020_NSW1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2020_QLD1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2020_SA1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2020_TAS1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2020_VIC1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2021_NSW1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2021_QLD1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2021_SA1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2021_TAS1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2021_VIC1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2022_NSW1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2022_QLD1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2022_SA1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2022_TAS1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2022_VIC1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2023_NSW1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2023_QLD1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2023_SA1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2023_TAS1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2023_VIC1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2024_NSW1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2024_QLD1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2024_SA1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2024_TAS1.csv
# Concatenated data saved to data/concatenated_data\PRICE_AND_DEMAND_2024_VIC1.csv

# %%
def concat_files_by_year():
    for region in regions:
        # Collect all files for the region across all years
        region_files = [
            os.path.join(data_dir, file) 
            for file in os.listdir(data_dir) 
            if file.endswith(f"_{region}.csv")
        ]

        # If no files found, skip
        if not region_files:
            print(f"No files found for {region}")
            continue

        # Load and concatenate CSV files
        data_frames = []
        for file in region_files:
            try:
                df = pd.read_csv(file)
                data_frames.append(df)
            except Exception as e:
                print(f"Failed to read {file}: {e}")

        # Concatenate and save the result
        if data_frames:
            concatenated_df = pd.concat(data_frames, ignore_index=True)
            # Sort by date to ensure chronological order
            concatenated_df['SETTLEMENTDATE'] = pd.to_datetime(concatenated_df['SETTLEMENTDATE'])
            concatenated_df = concatenated_df.sort_values('SETTLEMENTDATE')

            # split 'SETTLEMENTDATE' to year, month, day, hour, minute, and weekday
            concatenated_df['YEAR'] = concatenated_df['SETTLEMENTDATE'].dt.year
            concatenated_df['MONTH'] = concatenated_df['SETTLEMENTDATE'].dt.month
            concatenated_df['DAY'] = concatenated_df['SETTLEMENTDATE'].dt.day
            concatenated_df['HOUR'] = concatenated_df['SETTLEMENTDATE'].dt.hour
            concatenated_df['MINUTE'] = concatenated_df['SETTLEMENTDATE'].dt.minute
            concatenated_df['WEEKDAY'] = concatenated_df['SETTLEMENTDATE'].dt.weekday
            
            output_filename = f"PRICE_AND_DEMAND_ALL_YEARS_{region}.csv"
            output_path = os.path.join(out_dir, output_filename)
            concatenated_df.to_csv(output_path, index=False)
            print(f"Concatenated data for all years saved to {output_path}")

concat_files_by_year()
# Out:
# Concatenated data for all years saved to data/concatenated_data\PRICE_AND_DEMAND_ALL_YEARS_NSW1.csv
# Concatenated data for all years saved to data/concatenated_data\PRICE_AND_DEMAND_ALL_YEARS_QLD1.csv
# Concatenated data for all years saved to data/concatenated_data\PRICE_AND_DEMAND_ALL_YEARS_SA1.csv
# Concatenated data for all years saved to data/concatenated_data\PRICE_AND_DEMAND_ALL_YEARS_TAS1.csv
# Concatenated data for all years saved to data/concatenated_data\PRICE_AND_DEMAND_ALL_YEARS_VIC1.csv

# %%
# calculate the mean, median, min, max of the trading price by month of years (201901, 201902, ..., 202412)

def calculate_price_stats_by_month():
    for region in regions:
        input_filename = f"PRICE_AND_DEMAND_ALL_YEARS_{region}.csv"
        input_path = os.path.join(out_dir, input_filename)
        output_filename = f"PRICE_STATS_BY_MONTH_{region}.csv"
        output_path = os.path.join(analysis_dir, output_filename)

        try:
            df = pd.read_csv(input_path)
            df['SETTLEMENTDATE'] = pd.to_datetime(df['SETTLEMENTDATE'])
            df['YEAR_MONTH'] = df['SETTLEMENTDATE'].dt.strftime('%Y-%m')
            price_stats = df.groupby('YEAR_MONTH').agg(
                RRP_mean=('RRP', 'mean'),
                RRP_median=('RRP', 'median'),
                RRP_min=('RRP', 'min'),
                RRP_max=('RRP', 'max'),
                TOTALDEMAND_mean=('TOTALDEMAND', 'mean'),
                TOTALDEMAND_median=('TOTALDEMAND', 'median'),
                TOTALDEMAND_min=('TOTALDEMAND', 'min'),
                TOTALDEMAND_max=('TOTALDEMAND', 'max')
            ).round(2)
            #split 'YEAR_MONTH' to year and month
            price_stats['YEAR'] = price_stats.index.str.split('-').str[0]
            price_stats['MONTH'] = price_stats.index.str.split('-').str[1]

            # remove 2025 year data
            price_stats = price_stats[price_stats['YEAR'] != '2025']

            price_stats.to_csv(output_path)
            print(f"Price statistics by month saved to {output_path}")
        except Exception as e:
            print(f"Failed to calculate price statistics for {region}: {e}")
        

calculate_price_stats_by_month()
# Out:
# Price statistics by month saved to data/analysis\PRICE_STATS_BY_MONTH_NSW1.csv
# Price statistics by month saved to data/analysis\PRICE_STATS_BY_MONTH_QLD1.csv
# Price statistics by month saved to data/analysis\PRICE_STATS_BY_MONTH_SA1.csv
# Price statistics by month saved to data/analysis\PRICE_STATS_BY_MONTH_TAS1.csv
# Price statistics by month saved to data/analysis\PRICE_STATS_BY_MONTH_VIC1.csv

# %%
def calculate_price_stats_by_week():
    for region in regions:
        input_filename = f"PRICE_AND_DEMAND_ALL_YEARS_{region}.csv"
        input_path = os.path.join(out_dir, input_filename)
        output_filename = f"PRICE_STATS_BY_WEEK_{region}.csv"
        output_path = os.path.join(analysis_dir, output_filename)

        try:
            df = pd.read_csv(input_path)
            df['SETTLEMENTDATE'] = pd.to_datetime(df['SETTLEMENTDATE'])
            df['YEAR_WEEK'] = df['SETTLEMENTDATE'].dt.strftime('%Y-%U')  # Year-Week format
            price_stats = df.groupby('YEAR_WEEK').agg(
                RRP_mean=('RRP', 'mean'),
                RRP_median=('RRP', 'median'),
                RRP_min=('RRP', 'min'),
                RRP_max=('RRP', 'max'),
                TOTALDEMAND_mean=('TOTALDEMAND', 'mean'),
                TOTALDEMAND_median=('TOTALDEMAND', 'median'),
                TOTALDEMAND_min=('TOTALDEMAND', 'min'),
                TOTALDEMAND_max=('TOTALDEMAND', 'max')
            ).round(2)
            #split 'YEAR_WEEK' to year and week
            price_stats['YEAR'] = price_stats.index.str.split('-').str[0]
            price_stats['WEEK'] = price_stats.index.str.split('-').str[1]
            price_stats = price_stats[price_stats['YEAR'] != '2025']

            price_stats.to_csv(output_path)
            print(f"Price statistics by week saved to {output_path}")
        except Exception as e:
            print(f"Failed to calculate price statistics for {region}: {e}")

calculate_price_stats_by_week()
# Out:
# Price statistics by week saved to data/analysis\PRICE_STATS_BY_WEEK_NSW1.csv
# Price statistics by week saved to data/analysis\PRICE_STATS_BY_WEEK_QLD1.csv
# Price statistics by week saved to data/analysis\PRICE_STATS_BY_WEEK_SA1.csv
# Price statistics by week saved to data/analysis\PRICE_STATS_BY_WEEK_TAS1.csv
# Price statistics by week saved to data/analysis\PRICE_STATS_BY_WEEK_VIC1.csv

# %%
def calculate_price_stats_by_day():
    for region in regions:
        input_filename = f"PRICE_AND_DEMAND_ALL_YEARS_{region}.csv"
        input_path = os.path.join(out_dir, input_filename)
        output_filename = f"PRICE_STATS_BY_DAY_{region}.csv"
        output_path = os.path.join(analysis_dir, output_filename)

        try:
            df = pd.read_csv(input_path)
            df['SETTLEMENTDATE'] = pd.to_datetime(df['SETTLEMENTDATE'])
            df['YEAR_MONTH_DAY'] = df['SETTLEMENTDATE'].dt.strftime('%Y-%m-%d')
            price_stats = df.groupby('YEAR_MONTH_DAY').agg(
                RRP_mean=('RRP', 'mean'),
                RRP_median=('RRP', 'median'),
                RRP_min=('RRP', 'min'),
                RRP_max=('RRP', 'max'),
                TOTALDEMAND_mean=('TOTALDEMAND', 'mean'),
                TOTALDEMAND_median=('TOTALDEMAND', 'median'),
                TOTALDEMAND_min=('TOTALDEMAND', 'min'),
                TOTALDEMAND_max=('TOTALDEMAND', 'max')
            ).round(2)
            #split 'YEAR_MONTH_DAY' to year, month, and day
            price_stats['YEAR'] = price_stats.index.str.split('-').str[0]
            price_stats['MONTH'] = price_stats.index.str.split('-').str[1]
            price_stats['DAY'] = price_stats.index.str.split('-').str[2]
            price_stats['WEEKDAY'] = pd.to_datetime(price_stats.index).dayofweek
            price_stats = price_stats[price_stats['YEAR'] != '2025']

            price_stats.to_csv(output_path)
            print(f"Price statistics by day saved to {output_path}")
        except Exception as e:
            print(f"Failed to calculate price statistics for {region}: {e}")

calculate_price_stats_by_day()
# Out:
# Price statistics by day saved to data/analysis\PRICE_STATS_BY_DAY_NSW1.csv
# Price statistics by day saved to data/analysis\PRICE_STATS_BY_DAY_QLD1.csv
# Price statistics by day saved to data/analysis\PRICE_STATS_BY_DAY_SA1.csv
# Price statistics by day saved to data/analysis\PRICE_STATS_BY_DAY_TAS1.csv
# Price statistics by day saved to data/analysis\PRICE_STATS_BY_DAY_VIC1.csv

# %%
def calculate_price_stats_by_hour():
    for region in regions:
        input_filename = f"PRICE_AND_DEMAND_ALL_YEARS_{region}.csv"
        input_path = os.path.join(out_dir, input_filename)
        output_filename = f"PRICE_STATS_BY_HOUR_{region}.csv"
        output_path = os.path.join(analysis_dir, output_filename)

        try:
            df = pd.read_csv(input_path)
            df['SETTLEMENTDATE'] = pd.to_datetime(df['SETTLEMENTDATE'])
            df['YEAR_MONTH_DAY_HOUR'] = df['SETTLEMENTDATE'].dt.strftime('%Y-%m-%d %H:00')
            price_stats = df.groupby('YEAR_MONTH_DAY_HOUR').agg(
                RRP_mean=('RRP', 'mean'),
                RRP_median=('RRP', 'median'),
                RRP_min=('RRP', 'min'),
                RRP_max=('RRP', 'max'),
                TOTALDEMAND_mean=('TOTALDEMAND', 'mean'),
                TOTALDEMAND_median=('TOTALDEMAND', 'median'),
                TOTALDEMAND_min=('TOTALDEMAND', 'min'),
                TOTALDEMAND_max=('TOTALDEMAND', 'max')
            ).round(2)
            #split 'YEAR_MONTH_DAY_HOUR' to year, month, day, and hour
            price_stats['YEAR'] = price_stats.index.str.split('-').str[0]
            price_stats['MONTH'] = price_stats.index.str.split('-').str[1]
            price_stats['DAY'] = price_stats.index.str.split('-').str[2]
            price_stats['HOUR'] = price_stats.index.str.split(' ').str[1].str.split(':').str[0]
            price_stats['WEEKDAY'] = pd.to_datetime(price_stats.index).dayofweek
            price_stats = price_stats[price_stats['YEAR'] != '2025']

            price_stats.to_csv(output_path)
            print(f"Price statistics by hour saved to {output_path}")
        except Exception as e:
            print(f"Failed to calculate price statistics for {region}: {e}")

calculate_price_stats_by_hour()
# Out:
# Price statistics by hour saved to data/analysis\PRICE_STATS_BY_HOUR_NSW1.csv
# Price statistics by hour saved to data/analysis\PRICE_STATS_BY_HOUR_QLD1.csv
# Price statistics by hour saved to data/analysis\PRICE_STATS_BY_HOUR_SA1.csv
# Price statistics by hour saved to data/analysis\PRICE_STATS_BY_HOUR_TAS1.csv
# Price statistics by hour saved to data/analysis\PRICE_STATS_BY_HOUR_VIC1.csv

# %% [markdown]
# ## Outage

# %%
# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %%
# Download the latest data of NETWORK.NETWORK_OUTAGEDETAIL in MMS Data Model
# NETWORK.NETWORK_OUTAGEDETAIL stores the details of network outages in the NEM from 2003 to the present
# there is no need to download the table for each year and month
# The latest data can be found from the following URL: https://visualisations.aemo.com.au/aemo/nemweb/#mms-data-model

# 2025 January data
outage_detail_url = "https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_01/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE%23NETWORK_OUTAGEDETAIL%23FILE01%23202501010000.zip"

# Download the zip file
outage_detail_zipname = "data/aemo_data/NETWORK_OUTAGEDETAIL_202501.zip"
outage_detail_csvname = "PUBLIC_ARCHIVE#NETWORK_OUTAGEDETAIL#FILE01#202501010000.CSV"

try:
    response = requests.get(outage_detail_url, headers=headers)
    response.raise_for_status()
    with open(outage_detail_zipname, 'wb') as f:
        f.write(response.content)
    print(f"Downloaded {outage_detail_zipname}")

    # Unzip the file
    import zipfile
    with zipfile.ZipFile(outage_detail_zipname, 'r') as zip_ref:
        zip_ref.extractall("data/aemo_data")
    print(f"Unzipped {outage_detail_zipname}")
except requests.exceptions.RequestException as e:
    print(f"Failed to download {outage_detail_url}: {e}")
# Out:
# Downloaded data/aemo_data/NETWORK_OUTAGEDETAIL_202501.zip
# Unzipped data/aemo_data/NETWORK_OUTAGEDETAIL_202501.zip

# %%
# prepare the data for analysis

## remove first line and last line of the csv file
## STARTTIME,ENDTIME,SUBMITTEDDATE - "2003/03/15 07:00:00","2003/06/13 17:00:00","2003/04/29 12:13:51"
## filter data for 2022 and later using START_DATE
## save the prepared data to data/analysis/NETWORK_OUTAGEDETAIL.csv
## gzip the file

def prepare_outage_detail_data():
    input_filename = "data/aemo_data/PUBLIC_ARCHIVE#NETWORK_OUTAGEDETAIL#FILE01#202501010000.CSV"
    output_filename = "data/analysis/NETWORK_OUTAGEDETAIL_202201_202501.csv"

    try:
        df = pd.read_csv(input_filename, skiprows=1, skipfooter=1, engine='python')
        df['STARTTIME'] = pd.to_datetime(df['STARTTIME'])
        df = df[df['STARTTIME'].dt.year >= 2022]
        df.to_csv(output_filename, index=False)
        print(f"Prepared data saved to {output_filename}")
    except Exception as e:
        print(f"Failed to prepare data: {e}")

prepare_outage_detail_data()
# Out:
# Prepared data saved to data/analysis/NETWORK_OUTAGEDETAIL_202201_202501.csv.gz
